# %% [raw]
# ---
# title: "My Resume"
# output:
#   quarto::html_document:
#     css: |
#       .embedded-pdf {
#         width: 100%;
#         height: 90vh; /* Adjust the height as needed */
#       }
# ---

# %% [markdown]
# ```{include, class='embedded-pdf', src='./Resume_JonathanBarnes.pdf'}
